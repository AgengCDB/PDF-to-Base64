# %%
base64_str = """..."""

# %%
import base64

# %%
pdf_data = base64.b64decode(base64_str)
file_path = 'decoded_document.pdf'
with open(file_path, 'wb') as file:
    file.write(pdf_data)

# %%
print(pdf_data)
# Out:
# b'%PDF-1.7\n%\xe2\xe3\xcf\xd3\n7 0 obj\n<<\n/BitsPerComponent 8\n/ColorSpace /DeviceRGB\n/Height 91\n/Subtype /Image\n/Type /XObject\n/Width 115\n/Filter [/FlateDecode /DCTDecode]\n/DecodeParms [null <<\n/Quality 60\n>>]\n/Length 1572\n>>\nstream\nx\x9c\x9d\x94y8\xd4\t\x18\xc7\x7fcf\xcc\x18L\x8d1\xae\xad0\xaeqL\x87;\xa9\x1c\xcd\x18r4\xc3P\x8e\xc7U\xa4\x8c\xc9\x11i\xd3\x94bKC\xc6\x84\xe8\x10!\xf7QI\xb6Zi\xc8\xb1BL\xee(g\xc4t\x91\xcc2\xbf\xa5\xddv\xf7\x8f}\x9e=\xbe\xcf\xf3\xfd\xeb\xfb}\xde\xe7\xfd<\xef\xf3\xbc`/8\x00X\x03\xd2\x12(I\x14RZ\x12%\x89FK\xaf\xc1\xaa\xe0\xb022X\xadu\x1b\xe4U6jo\xd9\xbcQ\x9b\xa8g`f\xb7\xc3\xc0\x98l\xa2G\xb4p\xb3$\xdb;\xd2\x9ci\xfa;\xdc}\xdd\xf7\xf8\xd8QiN\xabC h4\x1a\x8b\xc1j\xe2p\x9aNFD#\xa7\xff,\xf01\x80A\x02\x1e@8\x14\x82\x07\xc40\x10(\x06\x02\xd6\x03\xca\x00\x00\x81C\xbe\n\xf8]\x101(\x0c.\x8e@\xae,\xbdR\xa8Z\x0b\x88A\xa0P1\x18\x14\x0e\x87\xc1V\xd2\x98\x95\x1c\x80a\xe02\xaa[,\xc5\xb1T_\x04>TV\xff4\'\x1b\xa9fUY\x87\xa3=\x7f\xafn\xe0\x17\x16+\x81\x92\x93WPT\x
# ...

# %%
def pdf_to_blob(file_path):
    # Read the PDF file in binary mode
    with open(file_path, 'rb') as pdf_file:
        binary_data = pdf_file.read()
    
    # Encode the binary data to base64
    blob_data = base64.b64encode(binary_data).decode('utf-8')
    
    return blob_data

# %%
# Example usage
pdf_blob = pdf_to_blob('decoded_document.pdf')
print(pdf_blob)
# Out:
# ...

# %%
if pdf_blob == base64_str:
    print("meong")
# Out:
# meong
